# %%
import pandas as pd
import distinctipy
import configs.itol_text as itol_text
import os

def get_info_list(df, col, id_field):
    info_list = [(df.at[i, id_field], df.at[i, col]) if pd.notna(df.at[i, col]) else (df.at[i, id_field], "None") for i in df.index]
    return info_list


def get_colour_dict(df, col):
    df = df.fillna("None")

    unique_values = df[col].unique()

    colour_set = [
        distinctipy.get_hex(x) for x in distinctipy.get_colors(len(unique_values))
    ]

    colour_dict = {
        value: colour_set[i % len(colour_set)] for i, value in enumerate(unique_values)
    }
    
    
    # If 'None' exists, assign it white color
    if "None" in colour_dict:
        colour_dict["None"] = "#FFFFFF"     

    return colour_dict


def generate_itol_colorstrip(col, colour_dict, info_list, output_filename):
    with open(output_filename, "w") as f:
        f.write(itol_text.dataset_colorstrip_text.replace("<custom_dataset_label>", col))
        for info, label in info_list:
            f.write(f"{info},{colour_dict[label]},{label} \n")

    print(f"File '{output_filename}' has been created.\n")


def generate_itol_ranges(col, colour_dict, info_list, output_filename):

    with open(output_filename, "w") as f:
        f.write(itol_text.dataset_ranges_text.replace("<custom_dataset_label>", col))
        for info, label in info_list:
            f.write(
                f"{info},{info},{colour_dict[label]},{colour_dict[label]},{colour_dict[label]},dashed,2,{label},black,italic\n"
            )

    print(f"File '{output_filename}' has been created.\n")


def generate_itol_text(col, info_list, output_filename):
    
    with open(output_filename, "w") as f:
        f.write(itol_text.dataset_text_text.replace("<custom_dataset_label>", col))
        for info, label in info_list:
            if label != "None":
                
                # Set ancestors / leaf labels differently
                if info[0] == "N" and info[1:].isdigit():
                    position = 1  # Set position to 1
                else:
                    position = -1  # Set position to -1
                f.write(f"{info},{label},{position},#0000ff,bold-italic,1,0 \n")

    print(f"File '{output_filename}' has been created.\n")

# %%
df = pd.read_csv("./kari_example.csv") # Dataframe with annotations
annotation_cols = [x for x in df.columns] # Columns you want to generate itol annotations for
outpath = "itol_output" # Folder to write out itol annotations
id_field = 'truncated_info' # ID field (will be skipped when making annotations)

df
# Out:
#                     truncated_info xref_orthodb         xref_supfam  \
# 0   tr|A0A2R6AP45|A0A2R6AP45_9ARCH          NaN  SSF48179;SSF51735;
# 1   tr|A0A7C5ICI9|A0A7C5ICI9_9ARCH          NaN  SSF48179;SSF51735;
# 2   tr|A0A6B2C402|A0A6B2C402_9ARCH          NaN  SSF48179;SSF51735;
# 3   tr|A0A151BJ71|A0A151BJ71_9ARCH          NaN  SSF48179;SSF51735;
# 4   tr|A0A511RIY9|A0A511RIY9_9DEIN  9804088at2;  SSF48179;SSF51735;
# 5           tr|D3PT81|D3PT81_MEIRD  9804088at2;  SSF48179;SSF51735;
# 6   tr|A0A0K9HJH1|A0A0K9HJH1_GEOSE  9804088at2;  SSF48179;SSF51735;
# 7           tr|F5L972|F5L972_CALTT  9804088at2;  SSF48179;SSF51735;
# 8   tr|A0A5T0UG45|A0A5T0UG45_CAMJU          NaN  SSF48179;SSF51735;
# 9                               N0          NaN                 NaN
# 10                              N1          NaN                 NaN
# 11                              N2          NaN                 NaN
# 12                              N3          NaN                 NaN
# 13                              N4          NaN                 NaN
# 14                              N5          NaN                 NaN
# 15                              N6          NaN                 NaN
# 16                              N7          NaN                 NaN
#
#    lineage_superkingdom             lineage_phylum  value
# 0               Archaea   Candidatus Marsarchaeota   0.23
# 1               Archaea           Nitrososphaerota   0.24
# 2               Archaea           Nitrososphaerota    NaN
# 3               Archaea  Candidatus Bathyarchaeota    NaN
# 4              Bacteria               Deinococcota    NaN
# 5              Bacteria               Deinococcota    NaN
# 6              Bacteria                  Bacillota    NaN
# 7              Bacteria                  Bacillota    NaN
# 8              Bacteria           Campylobacterota    NaN
# 9                   NaN                        NaN    NaN
# 10                  NaN                        NaN    NaN
# 11                  NaN                        NaN   0.45
# 12                  NaN                        NaN    NaN
# 13                  NaN                        NaN    NaN
# 14                  NaN                        NaN    NaN
# 15                  NaN                        NaN    NaN
# 16                  NaN                        NaN   0.36

# %%
if not os.path.exists(outpath):
    os.makedirs(outpath)

for col in annotation_cols:

    # Skip the info column, which won't be informative
    if col != id_field and col in df:


        colour_dict = get_colour_dict(df, col)
        
        info_list = get_info_list(df, col, id_field)
        
#         print (colour_dict)
#         print (info_list)

        # Can overwrite colour_dict here and pass custom colours.

        
        generate_itol_colorstrip(
            col, colour_dict, info_list,  f"{outpath}/{col}_itol_colorstrip.txt"
        )
        
        generate_itol_ranges(
            col, colour_dict, info_list, f"{outpath}/{col}_itol_ranges.txt"
        )

text_cols = ['value']

for text_col in text_cols:
    
    info_list = get_info_list(df, text_col, id_field)

        
    generate_itol_text(
        text_col, info_list, f"{outpath}/{text_col}_itol_text.txt"
    )
# Out:
# {'None': '#FFFFFF', '9804088at2;': '#f100f3'}
# [('tr|A0A2R6AP45|A0A2R6AP45_9ARCH', 'None'), ('tr|A0A7C5ICI9|A0A7C5ICI9_9ARCH', 'None'), ('tr|A0A6B2C402|A0A6B2C402_9ARCH', 'None'), ('tr|A0A151BJ71|A0A151BJ71_9ARCH', 'None'), ('tr|A0A511RIY9|A0A511RIY9_9DEIN', '9804088at2;'), ('tr|D3PT81|D3PT81_MEIRD', '9804088at2;'), ('tr|A0A0K9HJH1|A0A0K9HJH1_GEOSE', '9804088at2;'), ('tr|F5L972|F5L972_CALTT', '9804088at2;'), ('tr|A0A5T0UG45|A0A5T0UG45_CAMJU', 'None'), ('N0', 'None'), ('N1', 'None'), ('N2', 'None'), ('N3', 'None'), ('N4', 'None'), ('N5', 'None'), ('N6', 'None'), ('N7', 'None')]
#
# File 'itol_output/xref_orthodb_itol_colorstrip.txt' has been created.
#
# File 'itol_output/xref_orthodb_itol_ranges.txt' has been created.
#
# {'SSF48179;SSF51735;': '#00ff00', 'None': '#FFFFFF'}
# [('tr|A0A2R6AP45|A0A2R6AP45_9ARCH', 'SSF48179;SSF51735;'), ('tr|A0A7C5ICI9|A0A7C5ICI9_9ARCH', 'SSF48179;SSF51735;'), ('tr|A0A6B2C402|A0A6B2C402_9ARCH', 'SSF48179;SSF51735;'), ('tr|A0A151BJ71|A0A151BJ71_9ARCH', 'SSF48179;SSF51735;'), ('tr|A0A511RIY9|A0A511RIY9_9DEIN', 'SSF48179;SSF51735;'), ('tr|D3PT81|D3PT81_MEIRD', 'SSF48179;SSF51735;'), ('tr|A0A0K9HJH1|A0A0K9HJH1_GEOSE', 'SSF48179;SSF51735;'), ('tr|F5L972|F5L972_CALTT', 'SSF48179;SSF51735;'), ('tr|A0A5T0UG45|A0A5T0UG45_CAMJU', 'SSF48179;SSF51735;'), ('N0', 'None'), ('N1', 'None'), ('N2', 'None'), ('N3', 'None'), ('N4', 'None'), ('N5', 'None'), ('N6', 'None'), ('N7', 'None')]
#
# File 'itol_output/xref_supfam_itol_colorstrip.txt' has been created.
#
# File 'itol_output/xref_supfam_itol_ranges.txt' has been created.
#
# {'Archaea': '#00ff00', 'Bacteria': '#ff00ff', 'None': '#FFFFFF'}
# [('tr|A0A2R6AP45|A0A2R6AP45_9ARCH', 'Archaea'), ('tr|A0A7C5ICI9|A0A7C5ICI9_9ARCH', 'Archaea'), ('tr|A0A6B2C402|A0A6B2C402_9ARCH', 'Archaea'), ('tr|A0A151BJ71|A0A151BJ71_9ARCH', 'Archaea'), ('tr|A0A511RIY9|A0A511RIY9_9DEIN', 'Bacteria'), ('tr|D3PT81|D3PT81_MEIRD', 'Bacteria'), ('tr|A0A0K9HJH1|A0A0K9HJH1_GEOSE', 'Bacteria'), ('tr|F5L972|F5L972_CALTT', 'Bacteria'), ('tr|A0A5T0UG45|A0A5T0UG45_CAMJU', 'Bacteria'), ('N0', 'None'), ('N1', 'None'), ('N2', 'None'), ('N3', 'None'), ('N4', 'None'), ('N5', 'None'), ('N6', 'None'), ('N7', 'None')]
#
# File 'itol_output/lineage_superkingdom_itol_colorstrip.txt' has been created.
#
# File 'itol_output/lineage_superkingdom_itol_ranges.txt' has been created.
#
# {'Candidatus Marsarchaeota': '#00ff00', 'Nitrososphaerota': '#ff00ff', 'Candidatus Bathyarchaeota': '#0080ff', 'Deinococcota': '#ff8000', 'Bacillota': '#80bf80', 'Campylobacterota': '#651e99', 'None': '#FFFFFF'}
# [('tr|A0A2R6AP45|A0A2R6AP45_9ARCH', 'Candidatus Marsarchaeota'), ('tr|A0A7C5ICI9|A0A7C5ICI9_9ARCH', 'Nitrososphaerota'), ('tr|A0A6B2C402|A0A6B2C402_9ARCH', 'Nitrososphaerota'), ('tr|A0A151BJ71|A0A151BJ71_9ARCH', 'Candidatus Bathyarchaeota'), ('tr|A0A511RIY9|A0A511RIY9_9DEIN', 'Deinococcota'), ('tr|D3PT81|D3PT81_MEIRD', 'Deinococcota'), ('tr|A0A0K9HJH1|A0A0K9HJH1_GEOSE', 'Bacillota'), ('tr|F5L972|F5L972_CALTT', 'Bacillota'), ('tr|A0A5T0UG45|A0A5T0UG45_CAMJU', 'Campylobacterota'), ('N0', 'None'), ('N1', 'None'), ('N2', 'None'), ('N3', 'None'), ('N4', 'None'), ('N5', 'None'), ('N6', 'None'), ('N7', 'None')]
#
# File 'itol_output/lineage_phylum_itol_colorstrip.txt' has been created.
#
# File 'itol_output/lineage_phylum_itol_ranges.txt' has been created.
#
# {0.23: '#00ff00', 0.24: '#ea01e1', 'None': '#FFFFFF', 0.45: '#eb8402', 0.36: '#75d492'}
# [('tr|A0A2R6AP45|A0A2R6AP45_9ARCH', 0.23), ('tr|A0A7C5ICI9|A0A7C5ICI9_9ARCH', 0.24), ('tr|A0A6B2C402|A0A6B2C402_9ARCH', 'None'), ('tr|A0A151BJ71|A0A151BJ71_9ARCH', 'None'), ('tr|A0A511RIY9|A0A511RIY9_9DEIN', 'None'), ('tr|D3PT81|D3PT81_MEIRD', 'None'), ('tr|A0A0K9HJH1|A0A0K9HJH1_GEOSE', 'None'), ('tr|F5L972|F5L972_CALTT', 'None'), ('tr|A0A5T0UG45|A0A5T0UG45_CAMJU', 'None'), ('N0', 'None'), ('N1', 'None'), ('N2', 0.45), ('N3', 'None'), ('N4', 'None'), ('N5', 'None'), ('N6', 'None'), ('N7', 0.36)]
#
# File 'itol_output/value_itol_colorstrip.txt' has been created.
#
# File 'itol_output/value_itol_ranges.txt' has been created.
#
# File 'itol_output/value_itol_text.txt' has been created.
